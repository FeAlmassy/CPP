# %%
    idade = int(input("digite idade"))

    if 0 <= idade < 12:
        categoria = "crianca/bebe"
    elif  12 <= idade < 18:
        categoria = "adolescente"
    elif 18 <= idade < 30:
        categoria = "adulto jovem"
    elif 30 <= idade < 50:
        categoria = "adulto adulto"
    elif 50 <= idade < 75:
        categoria = "velho"
    elif 75 <= idade < 100:
        categoria = "velho pra porra"
    elif idade < 0:
        categoria = "nem nasceu"
    else:
        categoria = "morto"

    print(f"vc esta na categoria {categoria}")
# Out:
# vc esta na categoria nem nasceu

# %%
idades = range(-1, 101, 1)

for idade in idades:
    if 0 <= idade < 12:
        categoria = "crianca/bebe"

    elif  12 <= idade < 18:
        categoria = "adolescente"
    
    elif 18 <= idade < 30:
        categoria = "adulto jovem"
    
    elif 30 <= idade < 50:
        categoria = "adulto adulto"
    
    elif 50 <= idade < 75:
        categoria = "velho"
    
    elif 75 <= idade < 100:
        categoria = "velho pra porra"
    
    elif idade < 0:
        categoria = "nem nasceu"
    
    else:
        categoria = "morto"
    print(f"vc esta na categoria {categoria}")
# Out:
# vc esta na categoria nem nasceu
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria crianca/bebe
# vc esta na categoria adolescente
# vc esta na categoria adolescente
# vc esta na categoria adolescente
# vc esta na categoria adolescente
# vc esta na categoria adolescente
# vc esta na categoria adolescente
# vc esta na categoria adulto jovem
# vc esta na categoria adulto jovem
# vc esta na categoria adulto jovem
# vc esta na categoria adulto jovem
# vc esta na categoria adulto jovem
# vc esta na categoria adulto jovem
# vc esta na categoria adulto jovem
# vc esta na categoria adulto jovem
# vc esta na categoria adulto jovem
# ...

# %%
idade = input("digite idade")

# if type(idade) != int:
if isinstance(idade, int):
    print("vc digitou um valor invalido")
