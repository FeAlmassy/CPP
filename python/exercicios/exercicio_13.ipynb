# %%
dados = {
 "rogerio":[9,6,8],
 "lucas":[3,5,9],
 "bj":[0,2,5],
 "lisiane":[9,7,8]
}
lista_medias = []

for aluno in dados:
    media = (sum(dados[aluno])/3)
    lista_medias.append(media)
print(lista_medias)

lista_aprovacoes = []

for media in lista_medias:
    if media >= 7:
        situacao = "aprovado"
    elif media >= 5:
        situacao = "recuperacao"
    else:
        situacao = "reprovado"
# Out:
# [7.666666666666667, 5.666666666666667, 2.3333333333333335, 8.0]

# %%
alunos = [
    {"nome": "joao", "notas": [8.0, 7.5, 9.0]},
    {"nome": "maria", "notas": [7.5, 6.0, 5.0]},
    {"nome": "ana", "notas": [3.0, 5.5, 2.0]}
]

relatorio_final = []

for aluno in alunos:
    nome = aluno["nome"]
    notas = aluno["notas"]
    aprovado = []
    media = sum(notas) / 3

    if media >= 7.0:
        print(f"{nome} aprovado com: {round(media)}")
    
    elif media >= 5.0:
        print(f"{nome} recuperação com: {round(media)}")

    else:
        print(f"{nome} reprovado com {round(media)}")
    
    
    relatorio_final.append({"nome": nome, "media": round(media), "aprovado": aprovado})

resultados = relatorio_final
display(resultados)
# Out:
# joao aprovado com: 8
# maria recuperação com: 6
# ana reprovado com 4
# [{'nome': 'joao', 'media': 8, 'aprovado': []},
#  {'nome': 'maria', 'media': 6, 'aprovado': []},
#  {'nome': 'ana', 'media': 4, 'aprovado': []}]
