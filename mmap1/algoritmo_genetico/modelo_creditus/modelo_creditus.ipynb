# %%
import numpy as np
import pandas as pd

df  = pd.read_excel("BancoCreditus.xlsx")

dataframe_dados_clientes = df.iloc[:, 1:-1]  # ignora primeira coluna (índice) e última (gabarito)
dataframe_gabarito       = df.iloc[:, -1]    # sempre a última coluna

array_dados_clientes = dataframe_dados_clientes.values
array_gabarito       = dataframe_gabarito.values

qtd_features = array_dados_clientes.shape[1]
qtd_genes    = qtd_features + 1  # features + bias

print(f"Base carregada: {array_dados_clientes.shape[0]} clientes, {qtd_features} features")



def criar_cromossomos(qtd_cromossomos: int=6, qtd_genes: int=19) -> np.ndarray:
    return -1 + 2 * np.random.rand(qtd_cromossomos, qtd_genes)


def calcular_fitness(cromossomos: np.ndarray, array_dados_clientes: np.ndarray, array_gabarito: np.ndarray) -> np.ndarray:
    """
    Pega cada linha do array_cromossomos (menos o primeiro termo, que é o bias) e itera sobre cada linha da array de dados clientes
    cada linha (iteracao) e um produto escalar
    cada iteracao vai gerar um vetor coluna contendo 0 e 1 chamado de vetor hipotese

    depois comparar o vetor hipotese de cada cromossomo com o vetor gabarito e calcular a porcentagem de acerto

    depois calcular o fitness seguindo a formula 

    percentual_adimplente = quantidade de 1 no vetor hipotese/ total de 1 no gabarito
    percentual_inadimplente - quantidade de 0 no vetor hipotese/ total de 0 no gabarito

    fitness = percentual_adimplente * percentual_inadimplente

    cada cromossomo vai ter um fitness. Somar todos os fitness e calcular a porcentagem relativa de acerta de cada cromossomo
    com base nisso
    """

    total_adimplentes = np.sum(array_gabarito == 1)
    total_inadimplentes = np.sum(array_gabarito == 0)
    
    lista_hipotese = []

    #iteracao pra cada cromossomo
    for linha in cromossomos:  # o for num array vai de linha em linha automaticamente
        
        bias = linha[0]
        genes = linha[1:]

        q = np.dot(array_dados_clientes, genes) + bias

        #claudio ajudou, onde cada elemento de Q for maior igual a zero troque por 1, se nao troque por zero
        vetor_hipotese = np.where(q >= 0, 1, 0)

        acertos_adimplentes = np.sum((vetor_hipotese == 1) & (array_gabarito == 1)) #se a hipotese for 1 e o gabarito for 1 ele acertou, entao contabiliza
        acertos_inadimplentes = np.sum((vetor_hipotese == 0) & (array_gabarito == 0)) #se a hipotese for 0 e o gabarito for 0 ele acertou, entao contabiliza
        # se nao o & da false e ele nao soma 


        percentual_adimplente = acertos_adimplentes / total_adimplentes
        percentual_inadimplente = acertos_inadimplentes / total_inadimplentes

        fitness = percentual_adimplente * percentual_inadimplente
        
        lista_hipotese.append(fitness)
        vetor_fitness = np.array(lista_hipotese) 

    return vetor_fitness # cada cromossomo tem um fitness, entao o vetor de fitness tem o mesmo numero de linhas do array de cromossomos


def fitness_percentual(vetor_fitnesses: np.ndarray) -> np.ndarray:
    soma = np.sum(vetor_fitnesses)
    if soma == 0:
        return np.ones(len(vetor_fitnesses)) / len(vetor_fitnesses)
    return vetor_fitnesses / soma


def selecionar_pais_roleta(cromossomos: np.ndarray, percentual_fitnesses: np.ndarray) -> tuple[np.ndarray, np.ndarray]:
    roleta_acumulada = np.cumsum(percentual_fitnesses)

    indice_pai = min(int(np.searchsorted(roleta_acumulada, np.random.rand())), len(cromossomos) - 1)
    indice_mae = min(int(np.searchsorted(roleta_acumulada, np.random.rand())), len(cromossomos) - 1)

    return cromossomos[indice_pai], cromossomos[indice_mae]


def cruzar_pais(pai: np.ndarray, mae: np.ndarray) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    c1 = np.random.randint(1, len(pai))
    c2 = np.random.randint(1, len(pai))
    c3 = np.random.randint(1, len(pai))

    filho1 = np.concatenate([pai[:c1], mae[c1:]])
    filho2 = np.concatenate([pai[:c2], mae[c2:]])
    filho3 = np.concatenate([pai[:c3], mae[c3:]])

    return filho1, filho2, filho3


def mutar(filho1: np.ndarray, filho2: np.ndarray, filho3: np.ndarray, qtd_genes_mutados: int = 1,) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    Muta `qtd_genes_mutados` genes de cada filho, escolhidos sem reposição
    (nunca muta o mesmo gene duas vezes no mesmo filho).
    Cada gene mutado é resorteado uniformemente em [-1, 1].
    """
    for filho in [filho1, filho2, filho3]:
        # clip defensivo: nunca tenta mutar mais genes do que o cromossomo tem
        k = min(qtd_genes_mutados, len(filho))
        indices = np.random.choice(len(filho), size=k, replace=False)
        filho[indices] = -1 + 2 * np.random.rand(k)

    return filho1, filho2, filho3


def atualizar_populacao(cromossomos: np.ndarray,vetor_fitnesses: np.ndarray,filho1: np.ndarray,filho2: np.ndarray,filho3: np.ndarray,array_dados_clientes: np.ndarray,array_gabarito: np.ndarray,) -> np.ndarray:
    filhos = np.array([filho1, filho2, filho3])
    fitnesses_filhos = calcular_fitness(filhos, array_dados_clientes, array_gabarito)

    indices_melhores_filhos = np.argsort(fitnesses_filhos)[-2:] # pega os indices dos 2 melhores filhos, ou seja, os 2 filhos com maior fitness
    indices_piores          = np.argsort(vetor_fitnesses)[:2] # pega os indices dos 2 piores cromossomos da populacao, ou seja, os 2 cromossomos com menor fitness

    nova_populacao = cromossomos.copy()
    for i in range(2):
        idx_pior  = int(indices_piores[i])
        idx_filho = int(indices_melhores_filhos[i])
        nova_populacao[idx_pior] = filhos[idx_filho]

    return nova_populacao
# Out:
# Base carregada: 539 clientes, 18 features

# %%
def algoritmo_genetico(
    array_dados_clientes: np.ndarray,
    array_gabarito: np.ndarray,
    qtd_cromossomos: int = 6,
    qtd_genes: int = 19,
    qtd_genes_mutados: int = 1,
    geracoes: int = 100,
    fitness_alvo: float = 0.90,
) -> tuple[np.ndarray, float]:

    populacao = criar_cromossomos(qtd_cromossomos, qtd_genes)

    melhor_cromossomo = None
    melhor_fitness = 0.0

    for geracao in range(geracoes):
        fitnesses = calcular_fitness(populacao, array_dados_clientes, array_gabarito)
        percentuais = fitness_percentual(fitnesses)

        idx_melhor = int(np.argmax(fitnesses))
        fitness_atual = float(fitnesses[idx_melhor])

        if fitness_atual > melhor_fitness:
            melhor_fitness = fitness_atual
            melhor_cromossomo = populacao[idx_melhor].copy()

        print(f"Geração {geracao+1:>3} | melhor fitness: {melhor_fitness:.4f}")

        if melhor_fitness >= fitness_alvo:
            print(f"\nFitness alvo {fitness_alvo} atingido na geração {geracao+1}.")
            break

        pai, mae = selecionar_pais_roleta(populacao, percentuais)
        filho1, filho2, filho3 = cruzar_pais(pai, mae)
        filho1, filho2, filho3 = mutar(filho1, filho2, filho3, qtd_genes_mutados)
        populacao = atualizar_populacao(
            populacao, fitnesses,
            filho1, filho2, filho3,
            array_dados_clientes, array_gabarito,
        )

    return melhor_cromossomo, melhor_fitness

# %%
resultado = algoritmo_genetico(
    array_dados_clientes,
    array_gabarito,
    qtd_cromossomos=10,     
    qtd_genes_mutados=2,     
    geracoes=10000,
    fitness_alvo=0.95,
)
# Out:
# Geração   1 | melhor fitness: 0.6049
# Geração   2 | melhor fitness: 0.6049
# Geração   3 | melhor fitness: 0.6049
# Geração   4 | melhor fitness: 0.6049
# Geração   5 | melhor fitness: 0.6049
# Geração   6 | melhor fitness: 0.6049
# Geração   7 | melhor fitness: 0.6049
# Geração   8 | melhor fitness: 0.6049
# Geração   9 | melhor fitness: 0.6440
# Geração  10 | melhor fitness: 0.6440
# Geração  11 | melhor fitness: 0.6440
# Geração  12 | melhor fitness: 0.6440
# Geração  13 | melhor fitness: 0.6440
# Geração  14 | melhor fitness: 0.6440
# Geração  15 | melhor fitness: 0.6440
# Geração  16 | melhor fitness: 0.6440
# Geração  17 | melhor fitness: 0.6440
# Geração  18 | melhor fitness: 0.6440
# Geração  19 | melhor fitness: 0.6440
# Geração  20 | melhor fitness: 0.6440
# Geração  21 | melhor fitness: 0.6619
# Geração  22 | melhor fitness: 0.6619
# Geração  23 | melhor fitness: 0.6619
# Geração  24 | melhor fitness: 0.6781
# Geração  25 | melhor fitness: 0.6781
# Geração  26 | melhor fitness: 0.6781
# Geração  27 | melhor fitness: 0.6781
# Geração  28 | melhor fitness: 0.6781
# Geração  29 | melhor fitness: 0.6781
# Geração  30 | melhor fitness: 0.6781
# Geração  31 | melhor fitness: 0.6845
# Geração  32 | melhor fitness: 0.6845
# Geração  33 | melhor fitness: 0.6845
# Geração  34 | melhor fitness: 0.6845
# Geração  35 | melhor fitness: 0.6845
# Geração  36 | melhor fitness: 0.6845
# Geração  37 | melhor fitness: 0.6845
# Geração  38 | melhor fitness: 0.7058
# Geração  39 | melhor fitness: 0.7058
# Geração  40 | melhor fitness: 0.7241
# Geração  41 | melhor fitness: 0.7241
# Geração  42 | melhor fitness: 0.7241
# Geração  43 | melhor fitness: 0.7343
# Geração  44 | melhor fitness: 0.7343
# Geração  45 | melhor fitness: 0.7343
# Geração  46 | melhor fitness: 0.7343
# Geração  47 | melhor fitness: 0.7343
# Geração  48 | melhor fitness: 0.7343
# Geração  49 | melhor fitness: 0.7343
# Geração  50 | melhor fitness: 0.7343
# Geração  51 | melhor fitness: 0.7343
# Geração  52 | melhor fitness: 0.7343
# Geração  53 | melhor fitness: 0.7343
# Geração  54 | melhor fitness: 0.7343
# Geração  55 | melhor fitness: 0.7343
# Geração  56 | melhor fitness: 0.7343
# Geração  57 | melhor fitness: 0.7343
# Geração  58 | melhor fitness: 0.7343
# Geração  59 | melhor fitness: 0.7343
# Geração  60 | melhor fitness: 0.7343
# Geração  61 | melhor fitness: 0.7343
# Geração  62 | melhor fitness: 0.7343
# Geração  63 | melhor fitness: 0.7343
# Geração  64 | melhor fitness: 0.7343
# Geração  65 | melhor fitness: 0.7343
# Geração  66 | melhor fitness: 0.7455
# Geração  67 | melhor fitness: 0.7455
# Geração  68 | melhor fitness: 0.7455
# Geração  69 | melhor fitness: 0.7455
# Geração  70 | melhor fitness: 0.7455
# Geração  71 | melhor fitness: 0.7455
# Geração  72 | melhor fitness: 0.7455
# Geração  73 | melhor fitness: 0.7455
# Geração  74 | melhor fitness: 0.7455
# Geração  75 | melhor fitness: 0.7455
# Geração  76 | melhor fitness: 0.7455
# Geração  77 | melhor fitness: 0.7455
# Geração  78 | melhor fitness: 0.7455
# Geração  79 | melhor fitness: 0.7455
# Geração  80 | melhor fitness: 0.7455
# Geração  81 | melhor fitness: 0.7455
# Geração  82 | melhor fitness: 0.7455
# Geração  83 | melhor fitness: 0.7455
# Geração  84 | melhor fitness: 0.7455
# Geração  85 | melhor fitness: 0.7455
# Geração  86 | melhor fitness: 0.7455
# Geração  87 | melhor fitness: 0.7455
# Geração  88 | melhor fitness: 0.7455
# Geração  89 | melhor fitness: 0.7455
# Geração  90 | melhor fitness: 0.7455
# Geração  91 | melhor fitness: 0.7455
# Geração  92 | melhor fitness: 0.7455
# Geração  93 | melhor fitness: 0.7455
# Geração  94 | melhor fitness: 0.7455
# Geração  95 | melhor fitness: 0.7455
# Geração  96 | melhor fitness: 0.7455
# Geração  97 | melhor fitness: 0.7455
# Geração  98 | melhor fitness: 0.7455
# Geração  99 | melhor fitness: 0.7455
# Geração 100 | melhor fitness: 0.7455
# Geração 101 | melhor fitness: 0.7455
# Geração 102 | melhor fitness: 0.7455
# Geração 103 | melhor fitness: 0.7455
# Geração 104 | melhor fitness: 0.7455
# Geração 105 | melhor fitness: 0.7455
# Geração 106 | melhor fitness: 0.7455
# Geração 107 | melhor fitness: 0.7609
# Geração 108 | melhor fitness: 0.7609
# Geração 109 | melhor fitness: 0.7609
# Geração 110 | melhor fitness: 0.7609
# Geração 111 | melhor fitness: 0.7609
# Geração 112 | melhor fitness: 0.7609
# Geração 113 | melhor fitness: 0.7609
# Geração 114 | melhor fitness: 0.7609
# Geração 115 | melhor fitness: 0.7609
# Geração 116 | melhor fitness: 0.7609
# Geração 117 | melhor fitness: 0.7610
# Geração 118 | melhor fitness: 0.7610
# Geração 119 | melhor fitness: 0.7610
# Geração 120 | melhor fitness: 0.7610
# Geração 121 | melhor fitness: 0.7610
# Geração 122 | melhor fitness: 0.7610
# Geração 123 | melhor fitness: 0.7610
# Geração 124 | melhor fitness: 0.7610
# Geração 125 | melhor fitness: 0.7610
# Geração 126 | melhor fitness: 0.7610
# Geração 127 | melhor fitness: 0.7610
# Geração 128 | melhor fitness: 0.7610
# Geração 129 | melhor fitness: 0.7610
# Geração 130 | melhor fitness: 0.7610
# Geração 131 | melhor fitness: 0.7610
# Geração 132 | melhor fitness: 0.7610
# Geração 133 | melhor fitness: 0.7610
# Geração 134 | melhor fitness: 0.7610
# Geração 135 | melhor fitness: 0.7610
# Geração 136 | melhor fitness: 0.7610
# Geração 137 | melhor fitness: 0.7610
# Geração 138 | melhor fitness: 0.7649
# Geração 139 | melhor fitness: 0.7649
# Geração 140 | melhor fitness: 0.7649
# Geração 141 | melhor fitness: 0.7649
# Geração 142 | melhor fitness: 0.7676
# Geração 143 | melhor fitness: 0.7676
# Geração 144 | melhor fitness: 0.7676
# Geração 145 | melhor fitness: 0.7676
# Geração 146 | melhor fitness: 0.7676
# Geração 147 | melhor fitness: 0.7676
# Geração 148 | melhor fitness: 0.7676
# Geração 149 | melhor fitness: 0.7676
# Geração 150 | melhor fitness: 0.7676
# Geração 151 | melhor fitness: 0.7676
# Geração 152 | melhor fitness: 0.7676
# Geração 153 | melhor fitness: 0.7676
# Geração 154 | melhor fitness: 0.7676
# Geração 155 | melhor fitness: 0.7676
# Geração 156 | melhor fitness: 0.7676
# Geração 157 | melhor fitness: 0.7676
# Geração 158 | melhor fitness: 0.7676
# Geração 159 | melhor fitness: 0.7676
# Geração 160 | melhor fitness: 0.7676
# Geração 161 | melhor fitness: 0.7676
# Geração 162 | melhor fitness: 0.7676
# Geração 163 | melhor fitness: 0.7676
# Geração 164 | melhor fitness: 0.7676
# Geração 165 | melhor fitness: 0.7676
# Geração 166 | melhor fitness: 0.7676
# Geração 167 | melhor fitness: 0.7676
# Geração 168 | melhor fitness: 0.7676
# Geração 169 | melhor fitness: 0.7676
# Geração 170 | melhor fitness: 0.7676
# Geração 171 | melhor fitness: 0.7676
# Geração 172 | melhor fitness: 0.7676
# Geração 173 | melhor fitness: 0.7676
# Geração 174 | melhor fitness: 0.7774
# Geração 175 | melhor fitness: 0.7774
# Geração 176 | melhor fitness: 0.7774
# Geração 177 | melhor fitness: 0.7774
# Geração 178 | melhor fitness: 0.7774
# Geração 179 | melhor fitness: 0.7774
# Geração 180 | melhor fitness: 0.7774
# Geração 181 | melhor fitness: 0.7774
# Geração 182 | melhor fitness: 0.7774
# Geração 183 | melhor fitness: 0.7774
# Geração 184 | melhor fitness: 0.7774
# Geração 185 | melhor fitness: 0.7774
# Geração 186 | melhor fitness: 0.7774
# Geração 187 | melhor fitness: 0.7774
# Geração 188 | melhor fitness: 0.7774
# Geração 189 | melhor fitness: 0.7774
# Geração 190 | melhor fitness: 0.7774
# Geração 191 | melhor fitness: 0.7774
# Geração 192 | melhor fitness: 0.7774
# Geração 193 | melhor fitness: 0.7774
# Geração 194 | melhor fitness: 0.7774
# Geração 195 | melhor fitness: 0.7774
# Geração 196 | melhor fitness: 0.7774
# Geração 197 | melhor fitness: 0.7774
# Geração 198 | melhor fitness: 0.7774
# Geração 199 | melhor fitness: 0.7774
# Geração 200 | melhor fitness: 0.7774
# Geração 201 | melhor fitness: 0.7774
# Geração 202 | melhor fitness: 0.7774
# Geração 203 | melhor fitness: 0.7774
# Geração 204 | melhor fitness: 0.7774
# Geração 205 | melhor fitness: 0.7774
# Geração 206 | melhor fitness: 0.7774
# Geração 207 | melhor fitness: 0.7774
# Geração 208 | melhor fitness: 0.7774
# Geração 209 | melhor fitness: 0.7774
# Geração 210 | melhor fitness: 0.7774
# Geração 211 | melhor fitness: 0.7774
# Geração 212 | melhor fitness: 0.7774
# Geração 213 | melhor fitness: 0.7774
# Geração 214 | melhor fitness: 0.7774
# Geração 215 | melhor fitness: 0.7774
# Geração 216 | melhor fitness: 0.7774
# Geração 217 | melhor fitness: 0.7774
# Geração 218 | melhor fitness: 0.7774
# Geração 219 | melhor fitness: 0.7774
# Geração 220 | melhor fitness: 0.7774
# Geração 221 | melhor fitness: 0.7774
# Geração 222 | melhor fitness: 0.7774
# Geração 223 | melhor fitness: 0.7774
# Geração 224 | melhor fitness: 0.7774
# Geração 225 | melhor fitness: 0.7774
# Geração 226 | melhor fitness: 0.7774
# Geração 227 | melhor fitness: 0.7774
# Geração 228 | melhor fitness: 0.7774
# Geração 229 | melhor fitness: 0.7774
# Geração 230 | melhor fitness: 0.7774
# Geração 231 | melhor fitness: 0.7774
# Geração 232 | melhor fitness: 0.7774
# Geração 233 | melhor fitness: 0.7774
# Geração 234 | melhor fitness: 0.7774
# Geração 235 | melhor fitness: 0.7774
# Geração 236 | melhor fitness: 0.7774
# Geração 237 | melhor fitness: 0.7774
# Geração 238 | melhor fitness: 0.7774
# Geração 239 | melhor fitness: 0.7774
# Geração 240 | melhor fitness: 0.7774
# Geração 241 | melhor fitness: 0.7774
# Geração 242 | melhor fitness: 0.7774
# Geração 243 | melhor fitness: 0.7774
# Geração 244 | melhor fitness: 0.7774
# Geração 245 | melhor fitness: 0.7774
# Geração 246 | melhor fitness: 0.7774
# Geração 247 | melhor fitness: 0.7774
# Geração 248 | melhor fitness: 0.7774
# Geração 249 | melhor fitness: 0.7774
# Geração 250 | melhor fitness: 0.7774
# Geração 251 | melhor fitness: 0.7774
# Geração 252 | melhor fitness: 0.7774
# Geração 253 | melhor fitness: 0.7774
# Geração 254 | melhor fitness: 0.7774
# Geração 255 | melhor fitness: 0.7774
# Geração 256 | melhor fitness: 0.7774
# Geração 257 | melhor fitness: 0.7774
# Geração 258 | melhor fitness: 0.7774
# Geração 259 | melhor fitness: 0.7774
# Geração 260 | melhor fitness: 0.7774
# Geração 261 | melhor fitness: 0.7774
# Geração 262 | melhor fitness: 0.7774
# Geração 263 | melhor fitness: 0.7774
# Geração 264 | melhor fitness: 0.7774
# Geração 265 | melhor fitness: 0.7774
# Geração 266 | melhor fitness: 0.7774
# Geração 267 | melhor fitness: 0.7774
# Geração 268 | melhor fitness: 0.7774
# Geração 269 | melhor fitness: 0.7774
# Geração 270 | melhor fitness: 0.7774
# Geração 271 | melhor fitness: 0.7774
# Geração 272 | melhor fitness: 0.7774
# Geração 273 | melhor fitness: 0.7774
# Geração 274 | melhor fitness: 0.7774
# Geração 275 | melhor fitness: 0.7774
# Geração 276 | melhor fitness: 0.7919
# Geração 277 | melhor fitness: 0.7919
# Geração 278 | melhor fitness: 0.7919
# Geração 279 | melhor fitness: 0.7919
# Geração 280 | melhor fitness: 0.7919
# Geração 281 | melhor fitness: 0.7919
# Geração 282 | melhor fitness: 0.7919
# Geração 283 | melhor fitness: 0.7919
# Geração 284 | melhor fitness: 0.7919
# Geração 285 | melhor fitness: 0.7919
# Geração 286 | melhor fitness: 0.7919
# Geração 287 | melhor fitness: 0.7919
# Geração 288 | melhor fitness: 0.7919
# Geração 289 | melhor fitness: 0.7919
# Geração 290 | melhor fitness: 0.7919
# Geração 291 | melhor fitness: 0.7919
# Geração 292 | melhor fitness: 0.7919
# Geração 293 | melhor fitness: 0.7919
# Geração 294 | melhor fitness: 0.7919
# Geração 295 | melhor fitness: 0.7919
# Geração 296 | melhor fitness: 0.7919
# Geração 297 | melhor fitness: 0.7919
# Geração 298 | melhor fitness: 0.7919
# Geração 299 | melhor fitness: 0.7919
# Geração 300 | melhor fitness: 0.7919
# Geração 301 | melhor fitness: 0.7919
# Geração 302 | melhor fitness: 0.7919
# Geração 303 | melhor fitness: 0.7919
# Geração 304 | melhor fitness: 0.7919
# Geração 305 | melhor fitness: 0.7919
# Geração 306 | melhor fitness: 0.7919
# Geração 307 | melhor fitness: 0.7919
# Geração 308 | melhor fitness: 0.7919
# Geração 309 | melhor fitness: 0.7919
# Geração 310 | melhor fitness: 0.7919
# Geração 311 | melhor fitness: 0.7919
# Geração 312 | melhor fitness: 0.7919
# Geração 313 | melhor fitness: 0.7919
# Geração 314 | melhor fitness: 0.7919
# Geração 315 | melhor fitness: 0.7919
# Geração 316 | melhor fitness: 0.7919
# Geração 317 | melhor fitness: 0.7919
# Geração 318 | melhor fitness: 0.7919
# Geração 319 | melhor fitness: 0.7919
# Geração 320 | melhor fitness: 0.7919
# Geração 321 | melhor fitness: 0.7919
# Geração 322 | melhor fitness: 0.7919
# Geração 323 | melhor fitness: 0.7919
# Geração 324 | melhor fitness: 0.7919
# Geração 325 | melhor fitness: 0.7919
# Geração 326 | melhor fitness: 0.7919
# Geração 327 | melhor fitness: 0.7919
# Geração 328 | melhor fitness: 0.7919
# Geração 329 | melhor fitness: 0.7919
# Geração 330 | melhor fitness: 0.7919
# Geração 331 | melhor fitness: 0.7919
# Geração 332 | melhor fitness: 0.7919
# Geração 333 | melhor fitness: 0.7919
# Geração 334 | melhor fitness: 0.7919
# Geração 335 | melhor fitness: 0.7919
# Geração 336 | melhor fitness: 0.7919
# Geração 337 | melhor fitness: 0.7919
# Geração 338 | melhor fitness: 0.7919
# Geração 339 | melhor fitness: 0.7919
# Geração 340 | melhor fitness: 0.7919
# Geração 341 | melhor fitness: 0.7919
# Geração 342 | melhor fitness: 0.7919
# Geração 343 | melhor fitness: 0.7919
# Geração 344 | melhor fitness: 0.7919
# Geração 345 | melhor fitness: 0.7919
# Geração 346 | melhor fitness: 0.7919
# Geração 347 | melhor fitness: 0.7919
# Geração 348 | melhor fitness: 0.7919
# Geração 349 | melhor fitness: 0.7919
# Geração 350 | melhor fitness: 0.7919
# Geração 351 | melhor fitness: 0.7919
# Geração 352 | melhor fitness: 0.7919
# Geração 353 | melhor fitness: 0.7919
# Geração 354 | melhor fitness: 0.7919
# Geração 355 | melhor fitness: 0.7919
# Geração 356 | melhor fitness: 0.7919
# Geração 357 | melhor fitness: 0.7919
# Geração 358 | melhor fitness: 0.7919
# Geração 359 | melhor fitness: 0.7919
# Geração 360 | melhor fitness: 0.7919
# Geração 361 | melhor fitness: 0.7919
# Geração 362 | melhor fitness: 0.7919
# Geração 363 | melhor fitness: 0.7919
# Geração 364 | melhor fitness: 0.7919
# Geração 365 | melhor fitness: 0.7919
# Geração 366 | melhor fitness: 0.7919
# Geração 367 | melhor fitness: 0.7919
# Geração 368 | melhor fitness: 0.7919
# Geração 369 | melhor fitness: 0.7919
# Geração 370 | melhor fitness: 0.7919
# Geração 371 | melhor fitness: 0.7919
# Geração 372 | melhor fitness: 0.7919
# Geração 373 | melhor fitness: 0.7919
# Geração 374 | melhor fitness: 0.7919
# Geração 375 | melhor fitness: 0.7919
# Geração 376 | melhor fitness: 0.7919
# Geração 377 | melhor fitness: 0.7919
# Geração 378 | melhor fitness: 0.7919
# Geração 379 | melhor fitness: 0.7919
# Geração 380 | melhor fitness: 0.7919
# Geração 381 | melhor fitness: 0.7919
# Geração 382 | melhor fitness: 0.7919
# Geração 383 | melhor fitness: 0.7919
# Geração 384 | melhor fitness: 0.7919
# Geração 385 | melhor fitness: 0.7919
# Geração 386 | melhor fitness: 0.7919
# Geração 387 | melhor fitness: 0.7919
# Geração 388 | melhor fitness: 0.7919
# Geração 389 | melhor fitness: 0.7919
# Geração 390 | melhor fitness: 0.7919
# Geração 391 | melhor fitness: 0.7919
# Geração 392 | melhor fitness: 0.7919
# Geração 393 | melhor fitness: 0.7919
# Geração 394 | melhor fitness: 0.7919
# Geração 395 | melhor fitness: 0.7919
# Geração 396 | melhor fitness: 0.7919
# Geração 397 | melhor fitness: 0.7919
# Geração 398 | melhor fitness: 0.7919
# Geração 399 | melhor fitness: 0.7919
# Geração 400 | melhor fitness: 0.7919
# Geração 401 | melhor fitness: 0.7919
# Geração 402 | melhor fitness: 0.7919
# Geração 403 | melhor fitness: 0.7919
# Geração 404 | melhor fitness: 0.7919
# Geração 405 | melhor fitness: 0.7919
# Geração 406 | melhor fitness: 0.7919
# Geração 407 | melhor fitness: 0.7919
# Geração 408 | melhor fitness: 0.7919
# Geração 409 | melhor fitness: 0.7919
# Geração 410 | melhor fitness: 0.7919
# Geração 411 | melhor fitness: 0.7919
# Geração 412 | melhor fitness: 0.7919
# Geração 413 | melhor fitness: 0.7919
# Geração 414 | melhor fitness: 0.7919
# Geração 415 | melhor fitness: 0.7919
# Geração 416 | melhor fitness: 0.7919
# Geração 417 | melhor fitness: 0.7919
# Geração 418 | melhor fitness: 0.7919
# Geração 419 | melhor fitness: 0.7919
# Geração 420 | melhor fitness: 0.7919
# Geração 421 | melhor fitness: 0.7919
# Geração 422 | melhor fitness: 0.7919
# Geração 423 | melhor fitness: 0.7919
# Geração 424 | melhor fitness: 0.7919
# Geração 425 | melhor fitness: 0.7919
# Geração 426 | melhor fitness: 0.7919
# Geração 427 | melhor fitness: 0.7919
# Geração 428 | melhor fitness: 0.7919
# Geração 429 | melhor fitness: 0.7919
# Geração 430 | melhor fitness: 0.7919
# Geração 431 | melhor fitness: 0.7919
# Geração 432 | melhor fitness: 0.7919
# Geração 433 | melhor fitness: 0.7919
# Geração 434 | melhor fitness: 0.7919
# Geração 435 | melhor fitness: 0.7919
# Geração 436 | melhor fitness: 0.7919
# Geração 437 | melhor fitness: 0.7919
# Geração 438 | melhor fitness: 0.7919
# Geração 439 | melhor fitness: 0.7919
# Geração 440 | melhor fitness: 0.7919
# Geração 441 | melhor fitness: 0.7919
# Geração 442 | melhor fitness: 0.7919
# Geração 443 | melhor fitness: 0.7919
# Geração 444 | melhor fitness: 0.7919
# Geração 445 | melhor fitness: 0.7919
# Geração 446 | melhor fitness: 0.7919
# Geração 447 | melhor fitness: 0.7919
# Geração 448 | melhor fitness: 0.7919
# Geração 449 | melhor fitness: 0.7919
# Geração 450 | melhor fitness: 0.7919
# Geração 451 | melhor fitness: 0.7919
# Geração 452 | melhor fitness: 0.7919
# Geração 453 | melhor fitness: 0.7919
# Geração 454 | melhor fitness: 0.7919
# Geração 455 | melhor fitness: 0.7919
# Geração 456 | melhor fitness: 0.7919
# Geração 457 | melhor fitness: 0.7919
# Geração 458 | melhor fitness: 0.7919
# Geração 459 | melhor fitness: 0.7919
# Geração 460 | melhor fitness: 0.7919
# Geração 461 | melhor fitness: 0.7919
# Geração 462 | melhor fitness: 0.7919
# Geração 463 | melhor fitness: 0.7919
# Geração 464 | melhor fitness: 0.7919
# Geração 465 | melhor fitness: 0.7919
# Geração 466 | melhor fitness: 0.7919
# Geração 467 | melhor fitness: 0.7919
# Geração 468 | melhor fitness: 0.7919
# Geração 469 | melhor fitness: 0.7919
# Geração 470 | melhor fitness: 0.7919
# Geração 471 | melhor fitness: 0.7919
# Geração 472 | melhor fitness: 0.7919
# Geração 473 | melhor fitness: 0.7919
# Geração 474 | melhor fitness: 0.7919
# Geração 475 | melhor fitness: 0.7919
# Geração 476 | melhor fitness: 0.7919
# Geração 477 | melhor fitness: 0.7919
# Geração 478 | melhor fitness: 0.7919
# Geração 479 | melhor fitness: 0.7919
# Geração 480 | melhor fitness: 0.7919
# Geração 481 | melhor fitness: 0.7919
# Geração 482 | melhor fitness: 0.7919
# Geração 483 | melhor fitness: 0.7919
# Geração 484 | melhor fitness: 0.7919
# Geração 485 | melhor fitness: 0.7919
# Geração 486 | melhor fitness: 0.7919
# Geração 487 | melhor fitness: 0.7919
# Geração 488 | melhor fitness: 0.7919
# Geração 489 | melhor fitness: 0.7919
# Geração 490 | melhor fitness: 0.7919
# Geração 491 | melhor fitness: 0.7919
# Geração 492 | melhor fitness: 0.7965
# Geração 493 | melhor fitness: 0.7965
# Geração 494 | melhor fitness: 0.7965
# Geração 495 | melhor fitness: 0.7965
# Geração 496 | melhor fitness: 0.7965
# Geração 497 | melhor fitness: 0.7965
# Geração 498 | melhor fitness: 0.7965
# Geração 499 | melhor fitness: 0.7965
# Geração 500 | melhor fitness: 0.7965
# Geração 501 | melhor fitness: 0.7965
# Geração 502 | melhor fitness: 0.7965
# Geração 503 | melhor fitness: 0.7965
# Geração 504 | melhor fitness: 0.7965
# Geração 505 | melhor fitness: 0.7965
# Geração 506 | melhor fitness: 0.7965
# Geração 507 | melhor fitness: 0.7965
# Geração 508 | melhor fitness: 0.7965
# Geração 509 | melhor fitness: 0.7965
# Geração 510 | melhor fitness: 0.7965
# Geração 511 | melhor fitness: 0.7965
# Geração 512 | melhor fitness: 0.7965
# Geração 513 | melhor fitness: 0.7965
# Geração 514 | melhor fitness: 0.7965
# Geração 515 | melhor fitness: 0.7965
# Geração 516 | melhor fitness: 0.7965
# Geração 517 | melhor fitness: 0.7965
# Geração 518 | melhor fitness: 0.7965
# Geração 519 | melhor fitness: 0.7965
# Geração 520 | melhor fitness: 0.7965
# Geração 521 | melhor fitness: 0.7965
# Geração 522 | melhor fitness: 0.7965
# Geração 523 | melhor fitness: 0.7965
# Geração 524 | melhor fitness: 0.7965
# Geração 525 | melhor fitness: 0.7965
# Geração 526 | melhor fitness: 0.7965
# Geração 527 | melhor fitness: 0.7965
# Geração 528 | melhor fitness: 0.7965
# Geração 529 | melhor fitness: 0.7965
# Geração 530 | melhor fitness: 0.7965
# Geração 531 | melhor fitness: 0.7965
# Geração 532 | melhor fitness: 0.7965
# Geração 533 | melhor fitness: 0.7965
# Geração 534 | melhor fitness: 0.7965
# Geração 535 | melhor fitness: 0.7965
# Geração 536 | melhor fitness: 0.7965
# Geração 537 | melhor fitness: 0.7965
# Geração 538 | melhor fitness: 0.7965
# Geração 539 | melhor fitness: 0.7965
# Geração 540 | melhor fitness: 0.7965
# Geração 541 | melhor fitness: 0.7965
# Geração 542 | melhor fitness: 0.7965
# Geração 543 | melhor fitness: 0.7965
# Geração 544 | melhor fitness: 0.7965
# Geração 545 | melhor fitness: 0.7965
# Geração 546 | melhor fitness: 0.7965
# Geração 547 | melhor fitness: 0.7965
# Geração 548 | melhor fitness: 0.7965
# Geração 549 | melhor fitness: 0.7965
# Geração 550 | melhor fitness: 0.7965
# Geração 551 | melhor fitness: 0.7965
# Geração 552 | melhor fitness: 0.7965
# Geração 553 | melhor fitness: 0.7965
# Geração 554 | melhor fitness: 0.7965
# Geração 555 | melhor fitness: 0.7965
# Geração 556 | melhor fitness: 0.8048
# Geração 557 | melhor fitness: 0.8048
# Geração 558 | melhor fitness: 0.8048
# Geração 559 | melhor fitness: 0.8048
# Geração 560 | melhor fitness: 0.8048
# Geração 561 | melhor fitness: 0.8048
# Geração 562 | melhor fitness: 0.8048
# Geração 563 | melhor fitness: 0.8048
# Geração 564 | melhor fitness: 0.8048
# Geração 565 | melhor fitness: 0.8048
# Geração 566 | melhor fitness: 0.8048
# Geração 567 | melhor fitness: 0.8048
# Geração 568 | melhor fitness: 0.8048
# Geração 569 | melhor fitness: 0.8048
# Geração 570 | melhor fitness: 0.8048
# Geração 571 | melhor fitness: 0.8048
# Geração 572 | melhor fitness: 0.8048
# Geração 573 | melhor fitness: 0.8048
# Geração 574 | melhor fitness: 0.8048
# Geração 575 | melhor fitness: 0.8048
# Geração 576 | melhor fitness: 0.8048
# Geração 577 | melhor fitness: 0.8048
# Geração 578 | melhor fitness: 0.8048
# Geração 579 | melhor fitness: 0.8048
# Geração 580 | melhor fitness: 0.8048
# Geração 581 | melhor fitness: 0.8048
# Geração 582 | melhor fitness: 0.8048
# Geração 583 | melhor fitness: 0.8048
# Geração 584 | melhor fitness: 0.8048
# Geração 585 | melhor fitness: 0.8048
# Geração 586 | melhor fitness: 0.8048
# Geração 587 | melhor fitness: 0.8048
# Geração 588 | melhor fitness: 0.8048
# Geração 589 | melhor fitness: 0.8048
# Geração 590 | melhor fitness: 0.8048
# Geração 591 | melhor fitness: 0.8048
# Geração 592 | melhor fitness: 0.8048
# Geração 593 | melhor fitness: 0.8048
# Geração 594 | melhor fitness: 0.8048
# Geração 595 | melhor fitness: 0.8048
# Geração 596 | melhor fitness: 0.8048
# Geração 597 | melhor fitness: 0.8048
# Geração 598 | melhor fitness: 0.8048
# Geração 599 | melhor fitness: 0.8048
# Geração 600 | melhor fitness: 0.8048
# Geração 601 | melhor fitness: 0.8048
# Geração 602 | melhor fitness: 0.8048
# Geração 603 | melhor fitness: 0.8048
# Geração 604 | melhor fitness: 0.8048
# Geração 605 | melhor fitness: 0.8048
# Geração 606 | melhor fitness: 0.8048
# Geração 607 | melhor fitness: 0.8048
# Geração 608 | melhor fitness: 0.8048
# Geração 609 | melhor fitness: 0.8048
# Geração 610 | melhor fitness: 0.8048
# Geração 611 | melhor fitness: 0.8048
# Geração 612 | melhor fitness: 0.8048
# Geração 613 | melhor fitness: 0.8048
# Geração 614 | melhor fitness: 0.8048
# Geração 615 | melhor fitness: 0.8048
# Geração 616 | melhor fitness: 0.8048
# Geração 617 | melhor fitness: 0.8048
# Geração 618 | melhor fitness: 0.8048
# Geração 619 | melhor fitness: 0.8048
# Geração 620 | melhor fitness: 0.8048
# Geração 621 | melhor fitness: 0.8048
# Geração 622 | melhor fitness: 0.8048
# Geração 623 | melhor fitness: 0.8048
# Geração 624 | melhor fitness: 0.8048
# Geração 625 | melhor fitness: 0.8048
# Geração 626 | melhor fitness: 0.8048
# Geração 627 | melhor fitness: 0.8048
# Geração 628 | melhor fitness: 0.8048
# Geração 629 | melhor fitness: 0.8048
# Geração 630 | melhor fitness: 0.8048
# Geração 631 | melhor fitness: 0.8048
# Geração 632 | melhor fitness: 0.8048
# Geração 633 | melhor fitness: 0.8048
# Geração 634 | melhor fitness: 0.8048
# Geração 635 | melhor fitness: 0.8048
# Geração 636 | melhor fitness: 0.8048
# Geração 637 | melhor fitness: 0.8048
# Geração 638 | melhor fitness: 0.8048
# Geração 639 | melhor fitness: 0.8048
# Geração 640 | melhor fitness: 0.8048
# Geração 641 | melhor fitness: 0.8048
# Geração 642 | melhor fitness: 0.8048
# Geração 643 | melhor fitness: 0.8048
# Geração 644 | melhor fitness: 0.8048
# Geração 645 | melhor fitness: 0.8048
# Geração 646 | melhor fitness: 0.8048
# Geração 647 | melhor fitness: 0.8048
# Geração 648 | melhor fitness: 0.8048
# Geração 649 | melhor fitness: 0.8048
# Geração 650 | melhor fitness: 0.8048
# Geração 651 | melhor fitness: 0.8048
# Geração 652 | melhor fitness: 0.8048
# Geração 653 | melhor fitness: 0.8048
# Geração 654 | melhor fitness: 0.8048
# Geração 655 | melhor fitness: 0.8048
# Geração 656 | melhor fitness: 0.8048
# Geração 657 | melhor fitness: 0.8048
# Geração 658 | melhor fitness: 0.8048
# Geração 659 | melhor fitness: 0.8048
# Geração 660 | melhor fitness: 0.8048
# Geração 661 | melhor fitness: 0.8048
# Geração 662 | melhor fitness: 0.8048
# Geração 663 | melhor fitness: 0.8048
# Geração 664 | melhor fitness: 0.8048
# Geração 665 | melhor fitness: 0.8048
# Geração 666 | melhor fitness: 0.8048
# Geração 667 | melhor fitness: 0.8048
# Geração 668 | melhor fitness: 0.8048
# Geração 669 | melhor fitness: 0.8048
# Geração 670 | melhor fitness: 0.8048
# Geração 671 | melhor fitness: 0.8048
# Geração 672 | melhor fitness: 0.8048
# Geração 673 | melhor fitness: 0.8048
# Geração 674 | melhor fitness: 0.8048
# Geração 675 | melhor fitness: 0.8048
# Geração 676 | melhor fitness: 0.8048
# Geração 677 | melhor fitness: 0.8048
# Geração 678 | melhor fitness: 0.8048
# Geração 679 | melhor fitness: 0.8048
# Geração 680 | melhor fitness: 0.8048
# Geração 681 | melhor fitness: 0.8048
# Geração 682 | melhor fitness: 0.8048
# Geração 683 | melhor fitness: 0.8048
# Geração 684 | melhor fitness: 0.8048
# Geração 685 | melhor fitness: 0.8048
# Geração 686 | melhor fitness: 0.8048
# Geração 687 | melhor fitness: 0.8048
# Geração 688 | melhor fitness: 0.8048
# Geração 689 | melhor fitness: 0.8048
# Geração 690 | melhor fitness: 0.8048
# Geração 691 | melhor fitness: 0.8048
# Geração 692 | melhor fitness: 0.8048
# Geração 693 | melhor fitness: 0.8048
# Geração 694 | melhor fitness: 0.8048
# Geração 695 | melhor fitness: 0.8048
# Geração 696 | melhor fitness: 0.8048
# Geração 697 | melhor fitness: 0.8048
# Geração 698 | melhor fitness: 0.8048
# Geração 699 | melhor fitness: 0.8048
# Geração 700 | melhor fitness: 0.8048
# Geração 701 | melhor fitness: 0.8048
# Geração 702 | melhor fitness: 0.8048
# Geração 703 | melhor fitness: 0.8048
# Geração 704 | melhor fitness: 0.8048
# Geração 705 | melhor fitness: 0.8048
# Geração 706 | melhor fitness: 0.8048
# Geração 707 | melhor fitness: 0.8048
# Geração 708 | melhor fitness: 0.8048
# Geração 709 | melhor fitness: 0.8048
# Geração 710 | melhor fitness: 0.8048
# Geração 711 | melhor fitness: 0.8048
# Geração 712 | melhor fitness: 0.8048
# Geração 713 | melhor fitness: 0.8048
# Geração 714 | melhor fitness: 0.8048
# Geração 715 | melhor fitness: 0.8048
# Geração 716 | melhor fitness: 0.8048
# Geração 717 | melhor fitness: 0.8048
# Geração 718 | melhor fitness: 0.8048
# Geração 719 | melhor fitness: 0.8048
# Geração 720 | melhor fitness: 0.8048
# Geração 721 | melhor fitness: 0.8048
# Geração 722 | melhor fitness: 0.8048
# Geração 723 | melhor fitness: 0.8048
# Geração 724 | melhor fitness: 0.8048
# Geração 725 | melhor fitness: 0.8048
# Geração 726 | melhor fitness: 0.8048
# Geração 727 | melhor fitness: 0.8048
# Geração 728 | melhor fitness: 0.8048
# Geração 729 | melhor fitness: 0.8048
# Geração 730 | melhor fitness: 0.8048
# Geração 731 | melhor fitness: 0.8048
# Geração 732 | melhor fitness: 0.8048
# Geração 733 | melhor fitness: 0.8048
# Geração 734 | melhor fitness: 0.8048
# Geração 735 | melhor fitness: 0.8048
# Geração 736 | melhor fitness: 0.8048
# Geração 737 | melhor fitness: 0.8048
# Geração 738 | melhor fitness: 0.8048
# Geração 739 | melhor fitness: 0.8048
# Geração 740 | melhor fitness: 0.8048
# Geração 741 | melhor fitness: 0.8048
# Geração 742 | melhor fitness: 0.8048
# Geração 743 | melhor fitness: 0.8048
# Geração 744 | melhor fitness: 0.8048
# Geração 745 | melhor fitness: 0.8048
# Geração 746 | melhor fitness: 0.8048
# Geração 747 | melhor fitness: 0.8048
# Geração 748 | melhor fitness: 0.8048
# Geração 749 | melhor fitness: 0.8048
# Geração 750 | melhor fitness: 0.8048
# Geração 751 | melhor fitness: 0.8048
# Geração 752 | melhor fitness: 0.8048
# Geração 753 | melhor fitness: 0.8048
# Geração 754 | melhor fitness: 0.8048
# Geração 755 | melhor fitness: 0.8048
# Geração 756 | melhor fitness: 0.8048
# Geração 757 | melhor fitness: 0.8048
# Geração 758 | melhor fitness: 0.8048
# Geração 759 | melhor fitness: 0.8048
# Geração 760 | melhor fitness: 0.8048
# Geração 761 | melhor fitness: 0.8048
# Geração 762 | melhor fitness: 0.8048
# Geração 763 | melhor fitness: 0.8048
# Geração 764 | melhor fitness: 0.8048
# Geração 765 | melhor fitness: 0.8048
# Geração 766 | melhor fitness: 0.8048
# Geração 767 | melhor fitness: 0.8048
# Geração 768 | melhor fitness: 0.8048
# Geração 769 | melhor fitness: 0.8048
# Geração 770 | melhor fitness: 0.8048
# Geração 771 | melhor fitness: 0.8048
# Geração 772 | melhor fitness: 0.8048
# Geração 773 | melhor fitness: 0.8048
# Geração 774 | melhor fitness: 0.8048
# Geração 775 | melhor fitness: 0.8048
# Geração 776 | melhor fitness: 0.8048
# Geração 777 | melhor fitness: 0.8048
# Geração 778 | melhor fitness: 0.8048
# Geração 779 | melhor fitness: 0.8048
# Geração 780 | melhor fitness: 0.8048
# Geração 781 | melhor fitness: 0.8048
# Geração 782 | melhor fitness: 0.8048
# Geração 783 | melhor fitness: 0.8048
# Geração 784 | melhor fitness: 0.8048
# Geração 785 | melhor fitness: 0.8048
# Geração 786 | melhor fitness: 0.8048
# Geração 787 | melhor fitness: 0.8048
# Geração 788 | melhor fitness: 0.8048
# Geração 789 | melhor fitness: 0.8048
# Geração 790 | melhor fitness: 0.8048
# Geração 791 | melhor fitness: 0.8048
# Geração 792 | melhor fitness: 0.8048
# Geração 793 | melhor fitness: 0.8048
# Geração 794 | melhor fitness: 0.8048
# Geração 795 | melhor fitness: 0.8048
# Geração 796 | melhor fitness: 0.8048
# Geração 797 | melhor fitness: 0.8048
# Geração 798 | melhor fitness: 0.8048
# Geração 799 | melhor fitness: 0.8048
# Geração 800 | melhor fitness: 0.8048
# Geração 801 | melhor fitness: 0.8048
# Geração 802 | melhor fitness: 0.8048
# Geração 803 | melhor fitness: 0.8048
# Geração 804 | melhor fitness: 0.8048
# Geração 805 | melhor fitness: 0.8048
# Geração 806 | melhor fitness: 0.8048
# Geração 807 | melhor fitness: 0.8048
# Geração 808 | melhor fitness: 0.8048
# Geração 809 | melhor fitness: 0.8048
# Geração 810 | melhor fitness: 0.8048
# Geração 811 | melhor fitness: 0.8048
# Geração 812 | melhor fitness: 0.8048
# Geração 813 | melhor fitness: 0.8048
# Geração 814 | melhor fitness: 0.8048
# Geração 815 | melhor fitness: 0.8048
# Geração 816 | melhor fitness: 0.8048
# Geração 817 | melhor fitness: 0.8048
# Geração 818 | melhor fitness: 0.8048
# Geração 819 | melhor fitness: 0.8048
# Geração 820 | melhor fitness: 0.8048
# Geração 821 | melhor fitness: 0.8048
# Geração 822 | melhor fitness: 0.8048
# Geração 823 | melhor fitness: 0.8048
# Geração 824 | melhor fitness: 0.8048
# Geração 825 | melhor fitness: 0.8048
# Geração 826 | melhor fitness: 0.8048
# Geração 827 | melhor fitness: 0.8048
# Geração 828 | melhor fitness: 0.8048
# Geração 829 | melhor fitness: 0.8048
# Geração 830 | melhor fitness: 0.8048
# Geração 831 | melhor fitness: 0.8048
# Geração 832 | melhor fitness: 0.8048
# Geração 833 | melhor fitness: 0.8048
# Geração 834 | melhor fitness: 0.8048
# Geração 835 | melhor fitness: 0.8048
# Geração 836 | melhor fitness: 0.8048
# Geração 837 | melhor fitness: 0.8048
# Geração 838 | melhor fitness: 0.8048
# Geração 839 | melhor fitness: 0.8048
# Geração 840 | melhor fitness: 0.8048
# Geração 841 | melhor fitness: 0.8048
# Geração 842 | melhor fitness: 0.8048
# Geração 843 | melhor fitness: 0.8048
# Geração 844 | melhor fitness: 0.8048
# Geração 845 | melhor fitness: 0.8048
# Geração 846 | melhor fitness: 0.8048
# Geração 847 | melhor fitness: 0.8048
# Geração 848 | melhor fitness: 0.8048
# Geração 849 | melhor fitness: 0.8048
# Geração 850 | melhor fitness: 0.8048
# Geração 851 | melhor fitness: 0.8048
# Geração 852 | melhor fitness: 0.8048
# Geração 853 | melhor fitness: 0.8048
# Geração 854 | melhor fitness: 0.8048
# Geração 855 | melhor fitness: 0.8048
# Geração 856 | melhor fitness: 0.8048
# Geração 857 | melhor fitness: 0.8048
# Geração 858 | melhor fitness: 0.8048
# Geração 859 | melhor fitness: 0.8048
# Geração 860 | melhor fitness: 0.8048
# Geração 861 | melhor fitness: 0.8048
# Geração 862 | melhor fitness: 0.8048
# Geração 863 | melhor fitness: 0.8048
# Geração 864 | melhor fitness: 0.8048
# Geração 865 | melhor fitness: 0.8048
# Geração 866 | melhor fitness: 0.8048
# Geração 867 | melhor fitness: 0.8048
# Geração 868 | melhor fitness: 0.8048
# Geração 869 | melhor fitness: 0.8048
# Geração 870 | melhor fitness: 0.8048
# Geração 871 | melhor fitness: 0.8048
# Geração 872 | melhor fitness: 0.8048
# Geração 873 | melhor fitness: 0.8048
# Geração 874 | melhor fitness: 0.8048
# Geração 875 | melhor fitness: 0.8048
# Geração 876 | melhor fitness: 0.8048
# Geração 877 | melhor fitness: 0.8048
# Geração 878 | melhor fitness: 0.8048
# Geração 879 | melhor fitness: 0.8048
# Geração 880 | melhor fitness: 0.8048
# Geração 881 | melhor fitness: 0.8048
# Geração 882 | melhor fitness: 0.8048
# Geração 883 | melhor fitness: 0.8048
# Geração 884 | melhor fitness: 0.8048
# Geração 885 | melhor fitness: 0.8048
# Geração 886 | melhor fitness: 0.8048
# Geração 887 | melhor fitness: 0.8048
# Geração 888 | melhor fitness: 0.8048
# Geração 889 | melhor fitness: 0.8048
# Geração 890 | melhor fitness: 0.8048
# Geração 891 | melhor fitness: 0.8048
# Geração 892 | melhor fitness: 0.8048
# Geração 893 | melhor fitness: 0.8048
# Geração 894 | melhor fitness: 0.8048
# Geração 895 | melhor fitness: 0.8048
# Geração 896 | melhor fitness: 0.8048
# Geração 897 | melhor fitness: 0.8048
# Geração 898 | melhor fitness: 0.8048
# Geração 899 | melhor fitness: 0.8048
# Geração 900 | melhor fitness: 0.8048
# Geração 901 | melhor fitness: 0.8048
# Geração 902 | melhor fitness: 0.8048
# Geração 903 | melhor fitness: 0.8048
# Geração 904 | melhor fitness: 0.8048
# Geração 905 | melhor fitness: 0.8048
# Geração 906 | melhor fitness: 0.8048
# Geração 907 | melhor fitness: 0.8048
# Geração 908 | melhor fitness: 0.8048
# Geração 909 | melhor fitness: 0.8048
# Geração 910 | melhor fitness: 0.8048
# Geração 911 | melhor fitness: 0.8048
# Geração 912 | melhor fitness: 0.8048
# Geração 913 | melhor fitness: 0.8048
# Geração 914 | melhor fitness: 0.8048
# Geração 915 | melhor fitness: 0.8048
# Geração 916 | melhor fitness: 0.8048
# Geração 917 | melhor fitness: 0.8048
# Geração 918 | melhor fitness: 0.8048
# Geração 919 | melhor fitness: 0.8048
# Geração 920 | melhor fitness: 0.8048
# Geração 921 | melhor fitness: 0.8048
# Geração 922 | melhor fitness: 0.8048
# Geração 923 | melhor fitness: 0.8048
# Geração 924 | melhor fitness: 0.8048
# Geração 925 | melhor fitness: 0.8048
# Geração 926 | melhor fitness: 0.8048
# Geração 927 | melhor fitness: 0.8048
# Geração 928 | melhor fitness: 0.8048
# Geração 929 | melhor fitness: 0.8048
# Geração 930 | melhor fitness: 0.8048
# Geração 931 | melhor fitness: 0.8048
# Geração 932 | melhor fitness: 0.8048
# Geração 933 | melhor fitness: 0.8048
# Geração 934 | melhor fitness: 0.8048
# Geração 935 | melhor fitness: 0.8048
# Geração 936 | melhor fitness: 0.8048
# Geração 937 | melhor fitness: 0.8048
# Geração 938 | melhor fitness: 0.8048
# Geração 939 | melhor fitness: 0.8048
# Geração 940 | melhor fitness: 0.8048
# Geração 941 | melhor fitness: 0.8048
# Geração 942 | melhor fitness: 0.8048
# Geração 943 | melhor fitness: 0.8048
# Geração 944 | melhor fitness: 0.8048
# Geração 945 | melhor fitness: 0.8048
# Geração 946 | melhor fitness: 0.8048
# Geração 947 | melhor fitness: 0.8048
# Geração 948 | melhor fitness: 0.8048
# Geração 949 | melhor fitness: 0.8048
# Geração 950 | melhor fitness: 0.8048
# Geração 951 | melhor fitness: 0.8048
# Geração 952 | melhor fitness: 0.8048
# Geração 953 | melhor fitness: 0.8048
# Geração 954 | melhor fitness: 0.8048
# Geração 955 | melhor fitness: 0.8048
# Geração 956 | melhor fitness: 0.8048
# Geração 957 | melhor fitness: 0.8048
# Geração 958 | melhor fitness: 0.8048
# Geração 959 | melhor fitness: 0.8048
# Geração 960 | melhor fitness: 0.8048
# Geração 961 | melhor fitness: 0.8048
# Geração 962 | melhor fitness: 0.8048
# Geração 963 | melhor fitness: 0.8048
# Geração 964 | melhor fitness: 0.8048
# Geração 965 | melhor fitness: 0.8048
# Geração 966 | melhor fitness: 0.8048
# Geração 967 | melhor fitness: 0.8048
# Geração 968 | melhor fitness: 0.8048
# Geração 969 | melhor fitness: 0.8048
# Geração 970 | melhor fitness: 0.8048
# Geração 971 | melhor fitness: 0.8048
# Geração 972 | melhor fitness: 0.8048
# Geração 973 | melhor fitness: 0.8048
# Geração 974 | melhor fitness: 0.8048
# Geração 975 | melhor fitness: 0.8048
# Geração 976 | melhor fitness: 0.8048
# Geração 977 | melhor fitness: 0.8048
# Geração 978 | melhor fitness: 0.8048
# Geração 979 | melhor fitness: 0.8048
# Geração 980 | melhor fitness: 0.8048
# Geração 981 | melhor fitness: 0.8048
# Geração 982 | melhor fitness: 0.8048
# Geração 983 | melhor fitness: 0.8048
# Geração 984 | melhor fitness: 0.8048
# Geração 985 | melhor fitness: 0.8048
# Geração 986 | melhor fitness: 0.8048
# Geração 987 | melhor fitness: 0.8048
# Geração 988 | melhor fitness: 0.8048
# Geração 989 | melhor fitness: 0.8048
# Geração 990 | melhor fitness: 0.8048
# Geração 991 | melhor fitness: 0.8048
# Geração 992 | melhor fitness: 0.8048
# Geração 993 | melhor fitness: 0.8048
# Geração 994 | melhor fitness: 0.8048
# Geração 995 | melhor fitness: 0.8048
# Geração 996 | melhor fitness: 0.8048
# Geração 997 | melhor fitness: 0.8048
# Geração 998 | melhor fitness: 0.8048
# Geração 999 | melhor fitness: 0.8048
# Geração 1000 | melhor fitness: 0.8048
# Geração 1001 | melhor fitness: 0.8048
# Geração 1002 | melhor fitness: 0.8048
# Geração 1003 | melhor fitness: 0.8048
# Geração 1004 | melhor fitness: 0.8048
# Geração 1005 | melhor fitness: 0.8048
# Geração 1006 | melhor fitness: 0.8048
# Geração 1007 | melhor fitness: 0.8048
# Geração 1008 | melhor fitness: 0.8048
# Geração 1009 | melhor fitness: 0.8048
# Geração 1010 | melhor fitness: 0.8048
# Geração 1011 | melhor fitness: 0.8048
# Geração 1012 | melhor fitness: 0.8048
# Geração 1013 | melhor fitness: 0.8048
# Geração 1014 | melhor fitness: 0.8048
# Geração 1015 | melhor fitness: 0.8048
# Geração 1016 | melhor fitness: 0.8048
# Geração 1017 | melhor fitness: 0.8048
# Geração 1018 | melhor fitness: 0.8048
# Geração 1019 | melhor fitness: 0.8048
# Geração 1020 | melhor fitness: 0.8048
# Geração 1021 | melhor fitness: 0.8048
# Geração 1022 | melhor fitness: 0.8048
# Geração 1023 | melhor fitness: 0.8048
# Geração 1024 | melhor fitness: 0.8048
# Geração 1025 | melhor fitness: 0.8048
# Geração 1026 | melhor fitness: 0.8048
# Geração 1027 | melhor fitness: 0.8048
# Geração 1028 | melhor fitness: 0.8048
# Geração 1029 | melhor fitness: 0.8048
# Geração 1030 | melhor fitness: 0.8048
# Geração 1031 | melhor fitness: 0.8048
# Geração 1032 | melhor fitness: 0.8048
# Geração 1033 | melhor fitness: 0.8048
# Geração 1034 | melhor fitness: 0.8048
# Geração 1035 | melhor fitness: 0.8048
# Geração 1036 | melhor fitness: 0.8048
# Geração 1037 | melhor fitness: 0.8048
# Geração 1038 | melhor fitness: 0.8048
# Geração 1039 | melhor fitness: 0.8048
# Geração 1040 | melhor fitness: 0.8048
# Geração 1041 | melhor fitness: 0.8048
# Geração 1042 | melhor fitness: 0.8048
# Geração 1043 | melhor fitness: 0.8048
# Geração 1044 | melhor fitness: 0.8048
# Geração 1045 | melhor fitness: 0.8048
# Geração 1046 | melhor fitness: 0.8048
# Geração 1047 | melhor fitness: 0.8048
# Geração 1048 | melhor fitness: 0.8048
# Geração 1049 | melhor fitness: 0.8048
# Geração 1050 | melhor fitness: 0.8048
# Geração 1051 | melhor fitness: 0.8048
# Geração 1052 | melhor fitness: 0.8048
# Geração 1053 | melhor fitness: 0.8048
# Geração 1054 | melhor fitness: 0.8048
# Geração 1055 | melhor fitness: 0.8048
# Geração 1056 | melhor fitness: 0.8048
# Geração 1057 | melhor fitness: 0.8048
# Geração 1058 | melhor fitness: 0.8048
# Geração 1059 | melhor fitness: 0.8048
# Geração 1060 | melhor fitness: 0.8048
# Geração 1061 | melhor fitness: 0.8048
# Geração 1062 | melhor fitness: 0.8048
# Geração 1063 | melhor fitness: 0.8048
# Geração 1064 | melhor fitness: 0.8048
# Geração 1065 | melhor fitness: 0.8048
# Geração 1066 | melhor fitness: 0.8048
# Geração 1067 | melhor fitness: 0.8048
# Geração 1068 | melhor fitness: 0.8048
# Geração 1069 | melhor fitness: 0.8048
# Geração 1070 | melhor fitness: 0.8048
# Geração 1071 | melhor fitness: 0.8048
# Geração 1072 | melhor fitness: 0.8048
# Geração 1073 | melhor fitness: 0.8048
# Geração 1074 | melhor fitness: 0.8048
# Geração 1075 | melhor fitness: 0.8048
# Geração 1076 | melhor fitness: 0.8048
# Geração 1077 | melhor fitness: 0.8048
# Geração 1078 | melhor fitness: 0.8048
# Geração 1079 | melhor fitness: 0.8048
# Geração 1080 | melhor fitness: 0.8048
# Geração 1081 | melhor fitness: 0.8048
# Geração 1082 | melhor fitness: 0.8048
# Geração 1083 | melhor fitness: 0.8048
# Geração 1084 | melhor fitness: 0.8048
# Geração 1085 | melhor fitness: 0.8048
# Geração 1086 | melhor fitness: 0.8048
# Geração 1087 | melhor fitness: 0.8048
# Geração 1088 | melhor fitness: 0.8048
# Geração 1089 | melhor fitness: 0.8048
# Geração 1090 | melhor fitness: 0.8048
# Geração 1091 | melhor fitness: 0.8048
# Geração 1092 | melhor fitness: 0.8048
# Geração 1093 | melhor fitness: 0.8048
# Geração 1094 | melhor fitness: 0.8048
# Geração 1095 | melhor fitness: 0.8048
# Geração 1096 | melhor fitness: 0.8048
# Geração 1097 | melhor fitness: 0.8048
# Geração 1098 | melhor fitness: 0.8048
# Geração 1099 | melhor fitness: 0.8048
# Geração 1100 | melhor fitness: 0.8048
# Geração 1101 | melhor fitness: 0.8048
# Geração 1102 | melhor fitness: 0.8048
# Geração 1103 | melhor fitness: 0.8048
# Geração 1104 | melhor fitness: 0.8048
# Geração 1105 | melhor fitness: 0.8048
# Geração 1106 | melhor fitness: 0.8048
# Geração 1107 | melhor fitness: 0.8048
# Geração 1108 | melhor fitness: 0.8048
# Geração 1109 | melhor fitness: 0.8048
# Geração 1110 | melhor fitness: 0.8048
# Geração 1111 | melhor fitness: 0.8048
# Geração 1112 | melhor fitness: 0.8048
# Geração 1113 | melhor fitness: 0.8048
# Geração 1114 | melhor fitness: 0.8048
# Geração 1115 | melhor fitness: 0.8048
# Geração 1116 | melhor fitness: 0.8048
# Geração 1117 | melhor fitness: 0.8048
# Geração 1118 | melhor fitness: 0.8048
# Geração 1119 | melhor fitness: 0.8048
# Geração 1120 | melhor fitness: 0.8048
# Geração 1121 | melhor fitness: 0.8048
# Geração 1122 | melhor fitness: 0.8048
# Geração 1123 | melhor fitness: 0.8048
# Geração 1124 | melhor fitness: 0.8048
# Geração 1125 | melhor fitness: 0.8048
# Geração 1126 | melhor fitness: 0.8048
# Geração 1127 | melhor fitness: 0.8048
# Geração 1128 | melhor fitness: 0.8048
# Geração 1129 | melhor fitness: 0.8048
# Geração 1130 | melhor fitness: 0.8048
# Geração 1131 | melhor fitness: 0.8048
# Geração 1132 | melhor fitness: 0.8048
# Geração 1133 | melhor fitness: 0.8048
# Geração 1134 | melhor fitness: 0.8048
# Geração 1135 | melhor fitness: 0.8048
# Geração 1136 | melhor fitness: 0.8048
# Geração 1137 | melhor fitness: 0.8048
# Geração 1138 | melhor fitness: 0.8048
# Geração 1139 | melhor fitness: 0.8048
# Geração 1140 | melhor fitness: 0.8048
# Geração 1141 | melhor fitness: 0.8048
# Geração 1142 | melhor fitness: 0.8048
# Geração 1143 | melhor fitness: 0.8048
# Geração 1144 | melhor fitness: 0.8048
# Geração 1145 | melhor fitness: 0.8048
# Geração 1146 | melhor fitness: 0.8048
# Geração 1147 | melhor fitness: 0.8048
# Geração 1148 | melhor fitness: 0.8048
# Geração 1149 | melhor fitness: 0.8048
# Geração 1150 | melhor fitness: 0.8048
# Geração 1151 | melhor fitness: 0.8048
# Geração 1152 | melhor fitness: 0.8048
# Geração 1153 | melhor fitness: 0.8048
# Geração 1154 | melhor fitness: 0.8048
# Geração 1155 | melhor fitness: 0.8048
# Geração 1156 | melhor fitness: 0.8048
# Geração 1157 | melhor fitness: 0.8048
# Geração 1158 | melhor fitness: 0.8048
# Geração 1159 | melhor fitness: 0.8048
# Geração 1160 | melhor fitness: 0.8048
# Geração 1161 | melhor fitness: 0.8048
# Geração 1162 | melhor fitness: 0.8048
# Geração 1163 | melhor fitness: 0.8048
# Geração 1164 | melhor fitness: 0.8048
# Geração 1165 | melhor fitness: 0.8048
# Geração 1166 | melhor fitness: 0.8048
# Geração 1167 | melhor fitness: 0.8048
# Geração 1168 | melhor fitness: 0.8048
# Geração 1169 | melhor fitness: 0.8048
# Geração 1170 | melhor fitness: 0.8048
# Geração 1171 | melhor fitness: 0.8048
# Geração 1172 | melhor fitness: 0.8048
# Geração 1173 | melhor fitness: 0.8048
# Geração 1174 | melhor fitness: 0.8048
# Geração 1175 | melhor fitness: 0.8048
# Geração 1176 | melhor fitness: 0.8048
# Geração 1177 | melhor fitness: 0.8048
# Geração 1178 | melhor fitness: 0.8048
# Geração 1179 | melhor fitness: 0.8048
# Geração 1180 | melhor fitness: 0.8048
# Geração 1181 | melhor fitness: 0.8048
# Geração 1182 | melhor fitness: 0.8048
# Geração 1183 | melhor fitness: 0.8048
# Geração 1184 | melhor fitness: 0.8048
# Geração 1185 | melhor fitness: 0.8048
# Geração 1186 | melhor fitness: 0.8048
# Geração 1187 | melhor fitness: 0.8048
# Geração 1188 | melhor fitness: 0.8048
# Geração 1189 | melhor fitness: 0.8048
# Geração 1190 | melhor fitness: 0.8048
# Geração 1191 | melhor fitness: 0.8048
# Geração 1192 | melhor fitness: 0.8048
# Geração 1193 | melhor fitness: 0.8048
# Geração 1194 | melhor fitness: 0.8048
# Geração 1195 | melhor fitness: 0.8048
# Geração 1196 | melhor fitness: 0.8048
# Geração 1197 | melhor fitness: 0.8048
# Geração 1198 | melhor fitness: 0.8048
# Geração 1199 | melhor fitness: 0.8048
# Geração 1200 | melhor fitness: 0.8048
# Geração 1201 | melhor fitness: 0.8048
# Geração 1202 | melhor fitness: 0.8048
# Geração 1203 | melhor fitness: 0.8048
# Geração 1204 | melhor fitness: 0.8048
# Geração 1205 | melhor fitness: 0.8048
# Geração 1206 | melhor fitness: 0.8048
# Geração 1207 | melhor fitness: 0.8048
# Geração 1208 | melhor fitness: 0.8048
# Geração 1209 | melhor fitness: 0.8048
# Geração 1210 | melhor fitness: 0.8048
# Geração 1211 | melhor fitness: 0.8048
# Geração 1212 | melhor fitness: 0.8048
# Geração 1213 | melhor fitness: 0.8048
# Geração 1214 | melhor fitness: 0.8048
# Geração 1215 | melhor fitness: 0.8048
# Geração 1216 | melhor fitness: 0.8048
# Geração 1217 | melhor fitness: 0.8048
# Geração 1218 | melhor fitness: 0.8048
# Geração 1219 | melhor fitness: 0.8048
# Geração 1220 | melhor fitness: 0.8048
# Geração 1221 | melhor fitness: 0.8048
# Geração 1222 | melhor fitness: 0.8048
# Geração 1223 | melhor fitness: 0.8048
# Geração 1224 | melhor fitness: 0.8048
# Geração 1225 | melhor fitness: 0.8048
# Geração 1226 | melhor fitness: 0.8048
# Geração 1227 | melhor fitness: 0.8048
# Geração 1228 | melhor fitness: 0.8048
# Geração 1229 | melhor fitness: 0.8048
# Geração 1230 | melhor fitness: 0.8048
# Geração 1231 | melhor fitness: 0.8048
# Geração 1232 | melhor fitness: 0.8048
# Geração 1233 | melhor fitness: 0.8048
# Geração 1234 | melhor fitness: 0.8048
# Geração 1235 | melhor fitness: 0.8048
# Geração 1236 | melhor fitness: 0.8048
# Geração 1237 | melhor fitness: 0.8048
# Geração 1238 | melhor fitness: 0.8048
# Geração 1239 | melhor fitness: 0.8048
# Geração 1240 | melhor fitness: 0.8048
# Geração 1241 | melhor fitness: 0.8048
# Geração 1242 | melhor fitness: 0.8048
# Geração 1243 | melhor fitness: 0.8048
# Geração 1244 | melhor fitness: 0.8048
# Geração 1245 | melhor fitness: 0.8048
# Geração 1246 | melhor fitness: 0.8048
# Geração 1247 | melhor fitness: 0.8048
# Geração 1248 | melhor fitness: 0.8048
# Geração 1249 | melhor fitness: 0.8048
# Geração 1250 | melhor fitness: 0.8048
# Geração 1251 | melhor fitness: 0.8048
# Geração 1252 | melhor fitness: 0.8048
# Geração 1253 | melhor fitness: 0.8048
# Geração 1254 | melhor fitness: 0.8048
# Geração 1255 | melhor fitness: 0.8048
# Geração 1256 | melhor fitness: 0.8048
# Geração 1257 | melhor fitness: 0.8048
# Geração 1258 | melhor fitness: 0.8048
# Geração 1259 | melhor fitness: 0.8048
# Geração 1260 | melhor fitness: 0.8048
# Geração 1261 | melhor fitness: 0.8048
# Geração 1262 | melhor fitness: 0.8048
# Geração 1263 | melhor fitness: 0.8048
# Geração 1264 | melhor fitness: 0.8048
# Geração 1265 | melhor fitness: 0.8048
# Geração 1266 | melhor fitness: 0.8048
# Geração 1267 | melhor fitness: 0.8048
# Geração 1268 | melhor fitness: 0.8048
# Geração 1269 | melhor fitness: 0.8048
# Geração 1270 | melhor fitness: 0.8048
# Geração 1271 | melhor fitness: 0.8048
# Geração 1272 | melhor fitness: 0.8048
# Geração 1273 | melhor fitness: 0.8048
# Geração 1274 | melhor fitness: 0.8048
# Geração 1275 | melhor fitness: 0.8048
# Geração 1276 | melhor fitness: 0.8048
# Geração 1277 | melhor fitness: 0.8048
# Geração 1278 | melhor fitness: 0.8048
# Geração 1279 | melhor fitness: 0.8048
# Geração 1280 | melhor fitness: 0.8048
# Geração 1281 | melhor fitness: 0.8048
# Geração 1282 | melhor fitness: 0.8048
# Geração 1283 | melhor fitness: 0.8048
# Geração 1284 | melhor fitness: 0.8048
# Geração 1285 | melhor fitness: 0.8048
# Geração 1286 | melhor fitness: 0.8048
# Geração 1287 | melhor fitness: 0.8048
# Geração 1288 | melhor fitness: 0.8048
# Geração 1289 | melhor fitness: 0.8048
# ...
# Geração 9580 | melhor fitness: 0.8111
# Geração 9581 | melhor fitness: 0.8111
# Geração 9582 | melhor fitness: 0.8111
# Geração 9583 | melhor fitness: 0.8111
# Geração 9584 | melhor fitness: 0.8111
# Geração 9585 | melhor fitness: 0.8111
# Geração 9586 | melhor fitness: 0.8111
# Geração 9587 | melhor fitness: 0.8111
# Geração 9588 | melhor fitness: 0.8111
# Geração 9589 | melhor fitness: 0.8111
# Geração 9590 | melhor fitness: 0.8111
# Geração 9591 | melhor fitness: 0.8111
# Geração 9592 | melhor fitness: 0.8111
# Geração 9593 | melhor fitness: 0.8111
# Geração 9594 | melhor fitness: 0.8111
# Geração 9595 | melhor fitness: 0.8111
# Geração 9596 | melhor fitness: 0.8111
# Geração 9597 | melhor fitness: 0.8111
# Geração 9598 | melhor fitness: 0.8111
# Geração 9599 | melhor fitness: 0.8111
# Geração 9600 | melhor fitness: 0.8111
# Geração 9601 | melhor fitness: 0.8111
# Geração 9602 | melhor fitness: 0.8111
# Geração 9603 | melhor fitness: 0.8111
# Geração 9604 | melhor fitness: 0.8111
# Geração 9605 | melhor fitness: 0.8111
# Geração 9606 | melhor fitness: 0.8111
# Geração 9607 | melhor fitness: 0.8111
# Geração 9608 | melhor fitness: 0.8111
# Geração 9609 | melhor fitness: 0.8111
# Geração 9610 | melhor fitness: 0.8111
# Geração 9611 | melhor fitness: 0.8111
# Geração 9612 | melhor fitness: 0.8111
# Geração 9613 | melhor fitness: 0.8111
# Geração 9614 | melhor fitness: 0.8111
# Geração 9615 | melhor fitness: 0.8111
# Geração 9616 | melhor fitness: 0.8111
# Geração 9617 | melhor fitness: 0.8111
# Geração 9618 | melhor fitness: 0.8111
# Geração 9619 | melhor fitness: 0.8111
# Geração 9620 | melhor fitness: 0.8111
# Geração 9621 | melhor fitness: 0.8111
# Geração 9622 | melhor fitness: 0.8111
# Geração 9623 | melhor fitness: 0.8111
# Geração 9624 | melhor fitness: 0.8111
# Geração 9625 | melhor fitness: 0.8111
# Geração 9626 | melhor fitness: 0.8111
# Geração 9627 | melhor fitness: 0.8111
# Geração 9628 | melhor fitness: 0.8111
# Geração 9629 | melhor fitness: 0.8111
# Geração 9630 | melhor fitness: 0.8111
# Geração 9631 | melhor fitness: 0.8111
# Geração 9632 | melhor fitness: 0.8111
# Geração 9633 | melhor fitness: 0.8111
# Geração 9634 | melhor fitness: 0.8111
# Geração 9635 | melhor fitness: 0.8111
# Geração 9636 | melhor fitness: 0.8111
# Geração 9637 | melhor fitness: 0.8111
# Geração 9638 | melhor fitness: 0.8111
# Geração 9639 | melhor fitness: 0.8111
# Geração 9640 | melhor fitness: 0.8111
# Geração 9641 | melhor fitness: 0.8111
# Geração 9642 | melhor fitness: 0.8111
# Geração 9643 | melhor fitness: 0.8111
# Geração 9644 | melhor fitness: 0.8111
# Geração 9645 | melhor fitness: 0.8111
# Geração 9646 | melhor fitness: 0.8111
# Geração 9647 | melhor fitness: 0.8111
# Geração 9648 | melhor fitness: 0.8111
# Geração 9649 | melhor fitness: 0.8111
# Geração 9650 | melhor fitness: 0.8111
# Geração 9651 | melhor fitness: 0.8111
# Geração 9652 | melhor fitness: 0.8111
# Geração 9653 | melhor fitness: 0.8111
# Geração 9654 | melhor fitness: 0.8111
# Geração 9655 | melhor fitness: 0.8111
# Geração 9656 | melhor fitness: 0.8111
# Geração 9657 | melhor fitness: 0.8111
# Geração 9658 | melhor fitness: 0.8111
# Geração 9659 | melhor fitness: 0.8111
# Geração 9660 | melhor fitness: 0.8111
# Geração 9661 | melhor fitness: 0.8111
# Geração 9662 | melhor fitness: 0.8111
# Geração 9663 | melhor fitness: 0.8111
# Geração 9664 | melhor fitness: 0.8111
# Geração 9665 | melhor fitness: 0.8111
# Geração 9666 | melhor fitness: 0.8111
# Geração 9667 | melhor fitness: 0.8111
# Geração 9668 | melhor fitness: 0.8111
# Geração 9669 | melhor fitness: 0.8111
# Geração 9670 | melhor fitness: 0.8111
# Geração 9671 | melhor fitness: 0.8111
# Geração 9672 | melhor fitness: 0.8111
# Geração 9673 | melhor fitness: 0.8111
# Geração 9674 | melhor fitness: 0.8111
# Geração 9675 | melhor fitness: 0.8111
# Geração 9676 | melhor fitness: 0.8111
# Geração 9677 | melhor fitness: 0.8111
# Geração 9678 | melhor fitness: 0.8111
# Geração 9679 | melhor fitness: 0.8111
# Geração 9680 | melhor fitness: 0.8111
# Geração 9681 | melhor fitness: 0.8111
# Geração 9682 | melhor fitness: 0.8111
# Geração 9683 | melhor fitness: 0.8111
# Geração 9684 | melhor fitness: 0.8111
# Geração 9685 | melhor fitness: 0.8111
# Geração 9686 | melhor fitness: 0.8111
# Geração 9687 | melhor fitness: 0.8111
# Geração 9688 | melhor fitness: 0.8111
# Geração 9689 | melhor fitness: 0.8111
# Geração 9690 | melhor fitness: 0.8111
# Geração 9691 | melhor fitness: 0.8111
# Geração 9692 | melhor fitness: 0.8111
# Geração 9693 | melhor fitness: 0.8111
# Geração 9694 | melhor fitness: 0.8111
# Geração 9695 | melhor fitness: 0.8111
# Geração 9696 | melhor fitness: 0.8111
# Geração 9697 | melhor fitness: 0.8111
# Geração 9698 | melhor fitness: 0.8111
# Geração 9699 | melhor fitness: 0.8111
# Geração 9700 | melhor fitness: 0.8111
# Geração 9701 | melhor fitness: 0.8111
# Geração 9702 | melhor fitness: 0.8111
# Geração 9703 | melhor fitness: 0.8111
# Geração 9704 | melhor fitness: 0.8111
# Geração 9705 | melhor fitness: 0.8111
# Geração 9706 | melhor fitness: 0.8111
# Geração 9707 | melhor fitness: 0.8111
# Geração 9708 | melhor fitness: 0.8111
# Geração 9709 | melhor fitness: 0.8111
# Geração 9710 | melhor fitness: 0.8111
# Geração 9711 | melhor fitness: 0.8111
# Geração 9712 | melhor fitness: 0.8111
# Geração 9713 | melhor fitness: 0.8111
# Geração 9714 | melhor fitness: 0.8111
# Geração 9715 | melhor fitness: 0.8111
# Geração 9716 | melhor fitness: 0.8111
# Geração 9717 | melhor fitness: 0.8111
# Geração 9718 | melhor fitness: 0.8111
# Geração 9719 | melhor fitness: 0.8111
# Geração 9720 | melhor fitness: 0.8111
# Geração 9721 | melhor fitness: 0.8111
# Geração 9722 | melhor fitness: 0.8111
# Geração 9723 | melhor fitness: 0.8111
# Geração 9724 | melhor fitness: 0.8111
# Geração 9725 | melhor fitness: 0.8111
# Geração 9726 | melhor fitness: 0.8111
# Geração 9727 | melhor fitness: 0.8111
# Geração 9728 | melhor fitness: 0.8111
# Geração 9729 | melhor fitness: 0.8111
# Geração 9730 | melhor fitness: 0.8111
# Geração 9731 | melhor fitness: 0.8111
# Geração 9732 | melhor fitness: 0.8111
# Geração 9733 | melhor fitness: 0.8111
# Geração 9734 | melhor fitness: 0.8111
# Geração 9735 | melhor fitness: 0.8111
# Geração 9736 | melhor fitness: 0.8111
# Geração 9737 | melhor fitness: 0.8111
# Geração 9738 | melhor fitness: 0.8111
# Geração 9739 | melhor fitness: 0.8111
# Geração 9740 | melhor fitness: 0.8111
# Geração 9741 | melhor fitness: 0.8111
# Geração 9742 | melhor fitness: 0.8111
# Geração 9743 | melhor fitness: 0.8111
# Geração 9744 | melhor fitness: 0.8111
# Geração 9745 | melhor fitness: 0.8111
# Geração 9746 | melhor fitness: 0.8111
# Geração 9747 | melhor fitness: 0.8111
# Geração 9748 | melhor fitness: 0.8111
# Geração 9749 | melhor fitness: 0.8111
# Geração 9750 | melhor fitness: 0.8111
# Geração 9751 | melhor fitness: 0.8111
# Geração 9752 | melhor fitness: 0.8111
# Geração 9753 | melhor fitness: 0.8111
# Geração 9754 | melhor fitness: 0.8111
# Geração 9755 | melhor fitness: 0.8111
# Geração 9756 | melhor fitness: 0.8111
# Geração 9757 | melhor fitness: 0.8111
# Geração 9758 | melhor fitness: 0.8111
# Geração 9759 | melhor fitness: 0.8111
# Geração 9760 | melhor fitness: 0.8111
# Geração 9761 | melhor fitness: 0.8111
# Geração 9762 | melhor fitness: 0.8111
# Geração 9763 | melhor fitness: 0.8111
# Geração 9764 | melhor fitness: 0.8111
# Geração 9765 | melhor fitness: 0.8111
# Geração 9766 | melhor fitness: 0.8111
# Geração 9767 | melhor fitness: 0.8111
# Geração 9768 | melhor fitness: 0.8111
# Geração 9769 | melhor fitness: 0.8111
# Geração 9770 | melhor fitness: 0.8111
# Geração 9771 | melhor fitness: 0.8111
# Geração 9772 | melhor fitness: 0.8111
# Geração 9773 | melhor fitness: 0.8111
# Geração 9774 | melhor fitness: 0.8111
# Geração 9775 | melhor fitness: 0.8111
# Geração 9776 | melhor fitness: 0.8111
# Geração 9777 | melhor fitness: 0.8111
# Geração 9778 | melhor fitness: 0.8111
# Geração 9779 | melhor fitness: 0.8111
# Geração 9780 | melhor fitness: 0.8111
# Geração 9781 | melhor fitness: 0.8111
# Geração 9782 | melhor fitness: 0.8111
# Geração 9783 | melhor fitness: 0.8111
# Geração 9784 | melhor fitness: 0.8111
# Geração 9785 | melhor fitness: 0.8111
# Geração 9786 | melhor fitness: 0.8111
# Geração 9787 | melhor fitness: 0.8111
# Geração 9788 | melhor fitness: 0.8111
# Geração 9789 | melhor fitness: 0.8111
# Geração 9790 | melhor fitness: 0.8111
# Geração 9791 | melhor fitness: 0.8111
# Geração 9792 | melhor fitness: 0.8111
# Geração 9793 | melhor fitness: 0.8111
# Geração 9794 | melhor fitness: 0.8111
# Geração 9795 | melhor fitness: 0.8111
# Geração 9796 | melhor fitness: 0.8111
# Geração 9797 | melhor fitness: 0.8111
# Geração 9798 | melhor fitness: 0.8111
# Geração 9799 | melhor fitness: 0.8111
# Geração 9800 | melhor fitness: 0.8111
# Geração 9801 | melhor fitness: 0.8111
# Geração 9802 | melhor fitness: 0.8111
# Geração 9803 | melhor fitness: 0.8111
# Geração 9804 | melhor fitness: 0.8111
# Geração 9805 | melhor fitness: 0.8111
# Geração 9806 | melhor fitness: 0.8111
# Geração 9807 | melhor fitness: 0.8111
# Geração 9808 | melhor fitness: 0.8111
# Geração 9809 | melhor fitness: 0.8111
# Geração 9810 | melhor fitness: 0.8111
# Geração 9811 | melhor fitness: 0.8111
# Geração 9812 | melhor fitness: 0.8111
# Geração 9813 | melhor fitness: 0.8111
# Geração 9814 | melhor fitness: 0.8111
# Geração 9815 | melhor fitness: 0.8111
# Geração 9816 | melhor fitness: 0.8111
# Geração 9817 | melhor fitness: 0.8111
# Geração 9818 | melhor fitness: 0.8111
# Geração 9819 | melhor fitness: 0.8111
# Geração 9820 | melhor fitness: 0.8111
# Geração 9821 | melhor fitness: 0.8111
# Geração 9822 | melhor fitness: 0.8111
# Geração 9823 | melhor fitness: 0.8111
# Geração 9824 | melhor fitness: 0.8111
# Geração 9825 | melhor fitness: 0.8111
# Geração 9826 | melhor fitness: 0.8111
# Geração 9827 | melhor fitness: 0.8111
# Geração 9828 | melhor fitness: 0.8111
# Geração 9829 | melhor fitness: 0.8111
# Geração 9830 | melhor fitness: 0.8111
# Geração 9831 | melhor fitness: 0.8111
# Geração 9832 | melhor fitness: 0.8111
# Geração 9833 | melhor fitness: 0.8111
# Geração 9834 | melhor fitness: 0.8111
# Geração 9835 | melhor fitness: 0.8111
# Geração 9836 | melhor fitness: 0.8111
# Geração 9837 | melhor fitness: 0.8111
# Geração 9838 | melhor fitness: 0.8111
# Geração 9839 | melhor fitness: 0.8111
# Geração 9840 | melhor fitness: 0.8111
# Geração 9841 | melhor fitness: 0.8111
# Geração 9842 | melhor fitness: 0.8111
# Geração 9843 | melhor fitness: 0.8111
# Geração 9844 | melhor fitness: 0.8111
# Geração 9845 | melhor fitness: 0.8111
# Geração 9846 | melhor fitness: 0.8111
# Geração 9847 | melhor fitness: 0.8111
# Geração 9848 | melhor fitness: 0.8111
# Geração 9849 | melhor fitness: 0.8111
# Geração 9850 | melhor fitness: 0.8111
# Geração 9851 | melhor fitness: 0.8111
# Geração 9852 | melhor fitness: 0.8111
# Geração 9853 | melhor fitness: 0.8111
# Geração 9854 | melhor fitness: 0.8111
# Geração 9855 | melhor fitness: 0.8111
# Geração 9856 | melhor fitness: 0.8111
# Geração 9857 | melhor fitness: 0.8111
# Geração 9858 | melhor fitness: 0.8111
# Geração 9859 | melhor fitness: 0.8111
# Geração 9860 | melhor fitness: 0.8111
# Geração 9861 | melhor fitness: 0.8111
# Geração 9862 | melhor fitness: 0.8111
# Geração 9863 | melhor fitness: 0.8111
# Geração 9864 | melhor fitness: 0.8111
# Geração 9865 | melhor fitness: 0.8111
# Geração 9866 | melhor fitness: 0.8111
# Geração 9867 | melhor fitness: 0.8111
# Geração 9868 | melhor fitness: 0.8111
# Geração 9869 | melhor fitness: 0.8111
# Geração 9870 | melhor fitness: 0.8111
# Geração 9871 | melhor fitness: 0.8111
# Geração 9872 | melhor fitness: 0.8111
# Geração 9873 | melhor fitness: 0.8111
# Geração 9874 | melhor fitness: 0.8111
# Geração 9875 | melhor fitness: 0.8111
# Geração 9876 | melhor fitness: 0.8111
# Geração 9877 | melhor fitness: 0.8111
# Geração 9878 | melhor fitness: 0.8111
# Geração 9879 | melhor fitness: 0.8111
# Geração 9880 | melhor fitness: 0.8111
# Geração 9881 | melhor fitness: 0.8111
# Geração 9882 | melhor fitness: 0.8111
# Geração 9883 | melhor fitness: 0.8111
# Geração 9884 | melhor fitness: 0.8111
# Geração 9885 | melhor fitness: 0.8111
# Geração 9886 | melhor fitness: 0.8111
# Geração 9887 | melhor fitness: 0.8111
# Geração 9888 | melhor fitness: 0.8111
# Geração 9889 | melhor fitness: 0.8111
# Geração 9890 | melhor fitness: 0.8111
# Geração 9891 | melhor fitness: 0.8111
# Geração 9892 | melhor fitness: 0.8111
# Geração 9893 | melhor fitness: 0.8111
# Geração 9894 | melhor fitness: 0.8111
# Geração 9895 | melhor fitness: 0.8111
# Geração 9896 | melhor fitness: 0.8111
# Geração 9897 | melhor fitness: 0.8111
# Geração 9898 | melhor fitness: 0.8111
# Geração 9899 | melhor fitness: 0.8111
# Geração 9900 | melhor fitness: 0.8111
# Geração 9901 | melhor fitness: 0.8111
# Geração 9902 | melhor fitness: 0.8111
# Geração 9903 | melhor fitness: 0.8111
# Geração 9904 | melhor fitness: 0.8111
# Geração 9905 | melhor fitness: 0.8111
# Geração 9906 | melhor fitness: 0.8111
# Geração 9907 | melhor fitness: 0.8111
# Geração 9908 | melhor fitness: 0.8111
# Geração 9909 | melhor fitness: 0.8111
# Geração 9910 | melhor fitness: 0.8111
# Geração 9911 | melhor fitness: 0.8111
# Geração 9912 | melhor fitness: 0.8111
# Geração 9913 | melhor fitness: 0.8111
# Geração 9914 | melhor fitness: 0.8111
# Geração 9915 | melhor fitness: 0.8111
# Geração 9916 | melhor fitness: 0.8111
# Geração 9917 | melhor fitness: 0.8111
# Geração 9918 | melhor fitness: 0.8111
# Geração 9919 | melhor fitness: 0.8111
# Geração 9920 | melhor fitness: 0.8111
# Geração 9921 | melhor fitness: 0.8111
# Geração 9922 | melhor fitness: 0.8111
# Geração 9923 | melhor fitness: 0.8111
# Geração 9924 | melhor fitness: 0.8111
# Geração 9925 | melhor fitness: 0.8111
# Geração 9926 | melhor fitness: 0.8111
# Geração 9927 | melhor fitness: 0.8111
# Geração 9928 | melhor fitness: 0.8111
# Geração 9929 | melhor fitness: 0.8111
# Geração 9930 | melhor fitness: 0.8111
# Geração 9931 | melhor fitness: 0.8111
# Geração 9932 | melhor fitness: 0.8111
# Geração 9933 | melhor fitness: 0.8111
# Geração 9934 | melhor fitness: 0.8111
# Geração 9935 | melhor fitness: 0.8111
# Geração 9936 | melhor fitness: 0.8111
# Geração 9937 | melhor fitness: 0.8111
# Geração 9938 | melhor fitness: 0.8111
# Geração 9939 | melhor fitness: 0.8111
# Geração 9940 | melhor fitness: 0.8111
# Geração 9941 | melhor fitness: 0.8111
# Geração 9942 | melhor fitness: 0.8111
# Geração 9943 | melhor fitness: 0.8111
# Geração 9944 | melhor fitness: 0.8111
# Geração 9945 | melhor fitness: 0.8111
# Geração 9946 | melhor fitness: 0.8111
# Geração 9947 | melhor fitness: 0.8111
# Geração 9948 | melhor fitness: 0.8111
# Geração 9949 | melhor fitness: 0.8111
# Geração 9950 | melhor fitness: 0.8111
# Geração 9951 | melhor fitness: 0.8111
# Geração 9952 | melhor fitness: 0.8111
# Geração 9953 | melhor fitness: 0.8111
# Geração 9954 | melhor fitness: 0.8111
# Geração 9955 | melhor fitness: 0.8111
# Geração 9956 | melhor fitness: 0.8111
# Geração 9957 | melhor fitness: 0.8111
# Geração 9958 | melhor fitness: 0.8111
# Geração 9959 | melhor fitness: 0.8111
# Geração 9960 | melhor fitness: 0.8111
# Geração 9961 | melhor fitness: 0.8111
# Geração 9962 | melhor fitness: 0.8111
# Geração 9963 | melhor fitness: 0.8111
# Geração 9964 | melhor fitness: 0.8111
# Geração 9965 | melhor fitness: 0.8111
# Geração 9966 | melhor fitness: 0.8111
# Geração 9967 | melhor fitness: 0.8111
# Geração 9968 | melhor fitness: 0.8111
# Geração 9969 | melhor fitness: 0.8111
# Geração 9970 | melhor fitness: 0.8111
# Geração 9971 | melhor fitness: 0.8111
# Geração 9972 | melhor fitness: 0.8111
# Geração 9973 | melhor fitness: 0.8111
# Geração 9974 | melhor fitness: 0.8111
# Geração 9975 | melhor fitness: 0.8111
# Geração 9976 | melhor fitness: 0.8111
# Geração 9977 | melhor fitness: 0.8111
# Geração 9978 | melhor fitness: 0.8111
# Geração 9979 | melhor fitness: 0.8111
# Geração 9980 | melhor fitness: 0.8111
# Geração 9981 | melhor fitness: 0.8111
# Geração 9982 | melhor fitness: 0.8111
# Geração 9983 | melhor fitness: 0.8111
# Geração 9984 | melhor fitness: 0.8111
# Geração 9985 | melhor fitness: 0.8111
# Geração 9986 | melhor fitness: 0.8111
# Geração 9987 | melhor fitness: 0.8111
# Geração 9988 | melhor fitness: 0.8111
# Geração 9989 | melhor fitness: 0.8111
# Geração 9990 | melhor fitness: 0.8111
# Geração 9991 | melhor fitness: 0.8111
# Geração 9992 | melhor fitness: 0.8111
# Geração 9993 | melhor fitness: 0.8111
# Geração 9994 | melhor fitness: 0.8111
# Geração 9995 | melhor fitness: 0.8111
# Geração 9996 | melhor fitness: 0.8111
# Geração 9997 | melhor fitness: 0.8111
# Geração 9998 | melhor fitness: 0.8111
# Geração 9999 | melhor fitness: 0.8111
# Geração 10000 | melhor fitness: 0.8111
